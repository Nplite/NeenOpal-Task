# %%
import pandas as pd

# %%
df1 = pd.read_excel('D:\\INEURON\\Records Matching Task.xlsx')
df2 = pd.read_csv('D:\\INEURON\\Records Matching Task.xlsx - data2.csv')

# %%
df1.head()
# Out:
#          Order ID       Product ID  Qty
# 0  CA-2014-100006  TEC-PH-10002075    3
# 1  CA-2014-100090  FUR-TA-10003715    3
# 2  CA-2014-100090  OFF-BI-10001597    6
# 3  CA-2014-100293  OFF-PA-10000176    6
# 4  CA-2014-100328  OFF-BI-10000343    1

# %%
df2.head()
# Out:
#          Order ID       Product ID  Qty
# 0  CA-2014-100090  FUR-TA-10003715    3
# 1  CA-2014-100090  OFF-BI-10001597    6
# 2  CA-2014-100293  OFF-PA-10000176    6
# 3  CA-2014-100328  OFF-BI-10000343    1
# 4  CA-2014-100363  OFF-FA-10000611    2

# %% [markdown]
# ### How to identify the Records (Order ID + Product ID combination) present in data1 but missing in data2 (Specify the number of records missing in your answer)

# %%
df1["Record"] = df1["Order ID"]+df1["Product ID"]
df2["Record"] = df2["Order ID"]+df2["Product ID"]

[i for i in list(df1["Record"]) if i not in list(df2["Record"])]
# Out:
# ['CA-2014-100006TEC-PH-10002075',
#  'CA-2014-100678OFF-EN-10000056',
#  'CA-2014-100895OFF-AR-10004511',
#  'CA-2014-101560OFF-BI-10000309',
#  'CA-2014-102673OFF-LA-10001771',
#  'CA-2014-103366TEC-AC-10003628',
#  'CA-2014-103429OFF-PA-10001712',
#  'CA-2014-103940OFF-ST-10000943',
#  'CA-2014-103989FUR-FU-10003981',
#  'CA-2014-104738TEC-PH-10000576',
#  'CA-2014-105340OFF-BI-10001765',
#  'CA-2014-106726OFF-ST-10001496',
#  'CA-2014-107594TEC-PH-10002923',
#  'CA-2014-107811FUR-CH-10001394',
#  'CA-2014-108189OFF-FA-10000735',
#  'CA-2014-109918OFF-SU-10004290',
#  'CA-2014-109932OFF-PA-10001804',
#  'CA-2014-110065TEC-PH-10002468',
#  'CA-2014-110072FUR-FU-10000521',
#  'CA-2014-110639OFF-PA-10003936',
#  'CA-2014-110786OFF-PA-10000528',
#  'CA-2014-112291OFF-EN-10001415',
#  'CA-2014-112326OFF-LA-10003223',
#  'CA-2014-113257TEC-AC-10004171',
#  'CA-2014-113320FUR-FU-10004270',
#  'CA-2014-113362OFF-ST-10001809',
#  'CA-2014-113929OFF-EN-10003286',
# ...

# %%
len([i for i in list(df1["Record"]) if i not in list(df2["Record"])])
# Out:
# 507

# %% [markdown]
# ### How to identify the Records (Order ID + Product ID combination) missing in data1 but present in data2 (Specify the number of records missing in your answer)

# %%
[i for i in list(df2["Record"]) if i not in list(df1["Record"])]
# Out:
# ['CA-2014-100706TEC-AC-10001314',
#  'CA-2014-100762OFF-PA-10001815',
#  'CA-2014-101427OFF-AR-10002257',
#  'CA-2014-102652FUR-FU-10001918',
#  'CA-2014-102869OFF-PA-10000788',
#  'CA-2014-103310TEC-PH-10001817',
#  'CA-2014-103331OFF-PA-10002160',
#  'CA-2014-103492OFF-BI-10004817',
#  'CA-2014-104829OFF-PA-10003016',
#  'CA-2014-105165FUR-TA-10004154',
#  'CA-2014-105648FUR-TA-10002958',
#  'CA-2014-106439OFF-AR-10001419',
#  'CA-2014-106439TEC-AC-10004568',
#  'CA-2014-108861OFF-BI-10003876',
#  'CA-2014-110611OFF-ST-10000642',
#  'CA-2014-111150OFF-AR-10000034',
#  'CA-2014-111962OFF-BI-10001308',
#  'CA-2014-112158TEC-AC-10003628',
#  'CA-2014-113166OFF-PA-10001947',
#  'CA-2014-113271OFF-AR-10003251',
#  'CA-2014-113271OFF-PA-10002365',
#  'CA-2014-113383FUR-FU-10001986',
#  'CA-2014-113383OFF-AP-10004532',
#  'CA-2014-114314OFF-LA-10000240',
#  'CA-2014-114510OFF-ST-10003221',
#  'CA-2014-115056OFF-AP-10003971',
#  'CA-2014-115259OFF-FA-10000621',
# ...

# %%
len([i for i in list(df2["Record"]) if i not in list(df1["Record"])])
# Out:
# 508

# %% [markdown]
# ### Find the Sum of the total Qty of Records missing in data1 but present in data2

# %%
missing_data1 = [i for i in list(df2["Record"]) if i not in list(df1["Record"])]
missing_data2 = [i for i in list(df2["Record"]) if i not in list(df1["Record"])]

# %%
len(missing_data1 + missing_data2)
# Out:
# 1016

# %% [markdown]
# ### Find the total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2

# %%
alpha1 = df1["Record"].unique()
alpha2 = df2["Record"].unique()

# %%
len(alpha1)+len(alpha2)
# Out:
# 18957
